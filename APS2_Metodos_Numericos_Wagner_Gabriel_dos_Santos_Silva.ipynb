# %% [markdown]
# # APS Métodos Númericos

# %%
from scipy.linalg import svd
from skimage import data
from skimage.color import rgb2gray
from scipy.linalg import svd
import matplotlib.pyplot as plt
import numpy as np

# %%
gato = data.chelsea()
plt.imshow(gato)
gray_gato = rgb2gray(gato)

U,S,V_T = svd(gray_gato, full_matrices=False)
S = np.diag(S)
fig, ax = plt.subplots(3, 2, figsize=(10, 15))

curr_fig=0
for r in [60, 70, 80]:
  cat_approx=U[:, :r] @ S[0:r, :r] @ V_T[:r, :]
  ax[curr_fig][0].imshow(256-cat_approx)
  ax[curr_fig][0].set_title("k = "+str(r))
  ax[curr_fig,0].axis('off')
  ax[curr_fig][1].set_title("Original Image")
  ax[curr_fig][1].imshow(gray_gato)
  ax[curr_fig,1].axis('off')
  curr_fig +=1
plt.show()

# %%
gato.shape #Matriz da imagem
# Out:
# (300, 451, 3)

# %%
gray_gato.shape #Matriz da imagem
# Out:
# (300, 451)

# %%
U
# Out:
# array([[-0.05169698, -0.07354608,  0.0441153 , ..., -0.07988875,
#         -0.0584584 , -0.03824287],
#        [-0.0516497 , -0.07471783,  0.04653544, ...,  0.10084738,
#          0.14909323,  0.05003661],
#        [-0.05163224, -0.07531087,  0.05024318, ..., -0.02554351,
#         -0.18181389, -0.02204087],
#        ...,
#        [-0.06677288,  0.0311474 ,  0.03493233, ...,  0.00115441,
#         -0.00689057,  0.04745911],
#        [-0.0668638 ,  0.02720109,  0.03599754, ...,  0.02132047,
#          0.00986954, -0.00101149],
#        [-0.06691356,  0.02633296,  0.03607362, ...,  0.00043176,
#          0.04172398, -0.00479383]])

# %%
S
# Out:
# array([[1.70427845e+02, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.16412563e+01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.73935477e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.29343946e-02, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 2.28706468e-02, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 2.15307518e-02]])

# %%
V_T
# Out:
# array([[-0.04851108, -0.04826917, -0.04809735, ..., -0.0513346 ,
#         -0.05129698, -0.05123909],
#        [-0.13872869, -0.13975339, -0.13977431, ...,  0.07752516,
#          0.07770908,  0.07779836],
#        [ 0.03622185,  0.03726394,  0.03861645, ...,  0.00426306,
#          0.00440011,  0.00495034],
#        ...,
#        [ 0.0270361 , -0.00691155,  0.05534442, ...,  0.06770688,
#         -0.00511687,  0.14559302],
#        [-0.0514932 ,  0.03523579,  0.08264011, ...,  0.05158923,
#         -0.03541566, -0.07250193],
#        [-0.00818938,  0.02067411,  0.00056798, ..., -0.00528485,
#          0.02192733, -0.08231456]])
