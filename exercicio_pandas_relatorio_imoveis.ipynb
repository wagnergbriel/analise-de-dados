# %% [markdown]
# ## Relatório de análise

# %%
import pandas as pd

# %%
df = pd.read_csv("aluguel.csv", sep=";")

# %%
df.head(20)
# Out:
#            Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0   Apartamento                    Centro        1      0       0    15
# 1   Apartamento              Higienópolis        1      0       0    48
# 2   Apartamento                  Cachambi        2      0       0    50
# 3   Apartamento                    Grajaú        2      1       0    70
# 4   Apartamento       Lins de Vasconcelos        3      1       1    90
# 5   Apartamento                Copacabana        1      0       1    40
# 6   Apartamento   Freguesia (Jacarepaguá)        3      0       0    54
# 7   Apartamento           Barra da Tijuca        2      1       1    67
# 8   Apartamento                    Tijuca        2      1       0   110
# 9   Apartamento                    Olaria        3      1       0    68
# 10  Apartamento                    Tijuca        2      1       0    78
# 11  Apartamento                   Ipanema        3      1       1   125
# ...

# %% [markdown]
# ## Informações Gerais da Base de Dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19831 entries, 0 to 19830
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           19831 non-null  object
#  1   Bairro         19831 non-null  object
#  2   Quartos        19831 non-null  int64
#  3   Vagas          19831 non-null  int64
#  4   Suites         19831 non-null  int64
#  5   Area           19831 non-null  int64
#  6   Valor          19831 non-null  float64
#  7   Condominio     19831 non-null  float64
#  8   IPTU           19831 non-null  float64
#  9   Valor m2       19831 non-null  float64
#  10  Tipo Agregado  19831 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.7+ MB

# %%
df.shape
# Out:
# (19831, 11)

# %%
imoveis = df.shape[0]
variaveis = df.shape[1]
print(f"A base de dados contém {imoveis} registros e {variaveis} variáveis.")
# Out:
# A base de dados contém 19831 registros e 11 variáveis.

# %%
dados = df.dtypes

# %%
tipos_de_dados = pd.DataFrame(dados, columns=["Tipos de Dados"])

# %%
tipos_de_dados.columns.name = "Variaveis"

# %%
tipos_de_dados
# Out:
# Variaveis     Tipos de Dados
# Tipo                  object
# Bairro                object
# Quartos                int64
# Vagas                  int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Condominio           float64
# IPTU                 float64
# Valor m2             float64
# Tipo Agregado         object

# %% [markdown]
# ## Verificar os tipos de imoveis

# %%
tipos_de_imoveis =  df["Tipo"].drop_duplicates()

# %%
tipos_de_imoveis
# Out:
# 0               Apartamento
# 16923                  Casa
# 17821    Casa de Condomínio
# 18785          Casa de Vila
# 19018             Quitinete
# Name: Tipo, dtype: object

# %%
df_tipo_imoveis = pd.DataFrame(tipos_de_imoveis, index=range(tipos_de_imoveis.shape[0]), columns=["Tipos de Imoveis"])

# %%
df_tipo_imoveis
# Out:
#   Tipos de Imoveis
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
