# %% [markdown]
# # Exercicíos do curso Python Pandas do curso Alura 🐼 💻
#
#
# ##### **A base de dados com informações sobre imóveis disponíveis para alugueis, contendo as seguintes informações:**
#
#   *  Tipo
#   * Bairro
#   * Quartos
#   * Vagas
#   * Suites
#   * Area
#   * Valor
#   * Condominio
#   * IPTU
#
#
# ---

# %% [markdown]
# ## Relatório de análise

# %%
import pandas as pd

# %%
df = pd.read_csv("aluguel.csv", sep=";")

# %%
df.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# ---
#
#
#
#
#
# ## Informações Gerais da Base de Dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
df.shape
# Out:
# (32960, 9)

# %%
imoveis = df.shape[0]
variaveis = df.shape[1]
print(f"A base de dados contém {imoveis} registros e {variaveis} variáveis.")
# Out:
# A base de dados contém 32960 registros e 9 variáveis.

# %%
dados = df.dtypes

# %%
dados
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados, columns=["Tipos de Dados"])

# %%
tipos_de_dados.columns.name = "Variaveis"

# %%
tipos_de_dados
# Out:
# Variaveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %% [markdown]
# - - -
# ## Verificar os tipos de imoveis

# %%
tipos_de_imoveis =  [imoveis for imoveis in df["Tipo"].drop_duplicates()]

# %%
tipos_de_imoveis
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
df_tipo_imoveis = pd.DataFrame(tipos_de_imoveis, columns=["Tipo de imoveis"])

# %%
df_tipo_imoveis
# Out:
#                 Tipo de imoveis
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %% [markdown]
# - - -
# ## Eliminando dados de imoveis que não são residenciais

# %%
imoveis_residenciais = ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
df_residencial = df[df.Tipo.isin(imoveis_residenciais)== True]

# %%
#verificando se os imoveis não selecionados foram removidos
df_residencial.Tipo.drop_duplicates()
# Out:
# 0               Quitinete
# 1                    Casa
# 3             Apartamento
# 7      Casa de Condomínio
# 117          Casa de Vila
# Name: Tipo, dtype: object

# %%
df_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
imoveis_residenciais = df_residencial.shape[0]
variaveis = df_residencial.shape[1]
print(f"A base de dados contém {imoveis_residenciais} registros e {variaveis} variáveis.")
# Out:
# A base de dados contém 22580 registros e 9 variáveis.

# %%
print(f"Foram removidos {imoveis - imoveis_residenciais} registros em relação ao arquivo original")
# Out:
# Foram removidos 10380 registros em relação ao arquivo original

# %%
#Exportando arquivo que consta somente os dados de imoveis residenciais
df_residencial.to_csv("aluguel_imoveis_residenciais.csv", index=False, sep=";")

# %% [markdown]
# ---
# ## Verificar seleção e frequência dos imoveis residencias

# %% [markdown]
# *   Classificar imoveis do tipo Apartamento

# %%
imoveis_apartamento = df_residencial[df_residencial.Tipo == "Apartamento"]

# %%
imoveis_apartamento
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
print(f"Total de imoveis que são do tipo Apartamento: {imoveis_apartamento.shape[0]}")
# Out:
# Total de imoveis que são do tipo Apartamento: 19532

# %% [markdown]
# *   Classificar imoveis do tipo Casa

# %%
imoveis_casa = df_residencial[(df_residencial.Tipo != "Apartamento") & (df_residencial.Tipo != "Quitinete")]

# %%
imoveis_casa
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 7      Casa de Condomínio          Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                    Ramos        2      2       0
# 18     Casa de Condomínio                  Taquara        3      1       1
# 22     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 32908  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 32911                Casa            Bento Ribeiro        2      1       0
# 32924  Casa de Condomínio          Barra da Tijuca        3      5       3
# 32931                Casa                   Centro        5      0       1
# 32952  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
print(f"Total de imoveis que são do tipo Casa: {imoveis_casa.shape[0]}")
# Out:
# Total de imoveis que são do tipo Casa: 2212

# %% [markdown]
# *   Selecionar imoveis com área entre 60 e 100 m²

# %%
imoveis_area = df_residencial[(df_residencial.Area >= 60) & (df_residencial.Area <= 100)]

# %%
imoveis_area
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 5             Apartamento              Vista Alegre        3      1       0
# 8      Casa de Condomínio                     Ramos        2      2       0
# 11            Apartamento                    Grajaú        2      1       0
# 12            Apartamento       Lins de Vasconcelos        3      1       1
# ...                   ...                       ...      ...    ...     ...
# 32944         Apartamento  Recreio dos Bandeirantes        3      2       1
# 32947         Apartamento                    Leblon        3      0       1
# 32953         Apartamento                     Méier        2      0       0
# 32956         Apartamento               Jacarepaguá        3      1       2
# 32958         Apartamento                    Leblon        2      0       0
#
#        Area   Valor  Condominio   IPTU
# ...

# %%
print(f"Total de imoveis com área entre 60 e 100 m²: {imoveis_area.shape[0]}")
# Out:
# Total de imoveis com área entre 60 e 100 m²: 8719

# %% [markdown]
# *   Selecionar imoveis com pelo menos 4 quartos e aluguel menor que R$ 2.000

# %%
imoveis_quartos = df_residencial[(df_residencial.Quartos >= 4) & (df_residencial.Valor < 2000)]

# %%
imoveis_quartos
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 701           Apartamento  Recreio dos Bandeirantes        4      2       2
# 1465          Apartamento                   Taquara        4      1       1
# 2874                 Casa              Campo Grande        4      1       4
# 3075                 Casa         Engenho de Dentro        4      3       0
# 3218          Apartamento  Recreio dos Bandeirantes        4      2       2
# 3419         Casa de Vila                     Méier        4      0       1
# 5849                 Casa              Campo Grande        4      1       0
# 5852          Apartamento              Campo Grande        4      2       1
# 6456          Apartamento  Recreio dos Bandeirantes        4      2       1
# 7520          Apartamento               Cidade Nova        4      0       0
# 9716          Apartamento                 Pechincha        4      1       2
# ...

# %%
print(f"Total de imoveis com pelo menos de 4 quartos e aluguel menor que R$ 2.000: {imoveis_quartos.shape[0]}")
# Out:
# Total de imoveis com pelo menos de 4 quartos e aluguel menor que R$ 2.000: 41

# %% [markdown]
# - - -
# ## Tratamento de valores nulos

# %%
df_residencial.head(10)
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 1                 Casa  Jardim Botânico        2      0       1   100
# 3          Apartamento           Centro        1      0       0    15
# 4          Apartamento     Higienópolis        1      0       0    48
# 5          Apartamento     Vista Alegre        3      1       0    70
# 6          Apartamento         Cachambi        2      0       0    50
# 7   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8   Casa de Condomínio            Ramos        2      2       0    65
# 10         Apartamento           Centro        1      0       0    36
# 11         Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio  IPTU
# 0    1700.0       500.0  60.0
# 1    7000.0         NaN   NaN
# 3     800.0       390.0  20.0
# 4     800.0       230.0   NaN
# 5    1200.0         NaN   NaN
# ...

# %%
df_residencial.isnull() #Observando quais valores são nulos
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32953  False   False    False  False   False  False  False       False  False
# 32955  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [22580 rows x 9 columns]

# %%
df_residencial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22580 entries, 0 to 32958
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df_residencial[df_residencial["Valor"].isnull()]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 76     Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 2186   Apartamento             Leme        2      0       0    75    NaN
# 2456          Casa     Campo Grande        3      4       3   363    NaN
# 2941   Apartamento         Botafogo        2      0       0    95    NaN
# 2973   Apartamento       Copacabana        2      0       0    72    NaN
# 7302          Casa     Campo Grande        3      2       1   100    NaN
# 12683  Apartamento             Leme        2      0       1    75    NaN
# 13229  Apartamento           Glória        3      0       1   135    NaN
# 13525  Apartamento            Gávea        3      1       1   105    NaN
#
#        Condominio   IPTU
# 76          970.0   68.0
# 2186        878.0    NaN
# 2456          NaN    NaN
# 2941       1010.0  170.0
# 2973        850.0    NaN
# 7302          NaN    NaN
# 12683       878.0    NaN
# 13229       910.0  228.0
# ...

# %%
df_residencial["Valor"].isnull()
# Out:
# 0        False
# 1        False
# 3        False
# 4        False
# 5        False
#          ...
# 32953    False
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# Name: Valor, Length: 22580, dtype: bool

# %%
df_residencial.shape[0]
# Out:
# 22580

# %%
df_residencial.dropna(subset=["Valor"], inplace=True) #substituindo os valores nulos por zero
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df_residencial[df_residencial["Valor"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df_residencial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22571 entries, 0 to 32958
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22571 non-null  object
#  1   Bairro      22571 non-null  object
#  2   Quartos     22571 non-null  int64
#  3   Vagas       22571 non-null  int64
#  4   Suites      22571 non-null  int64
#  5   Area        22571 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20758 non-null  float64
#  8   IPTU        15791 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ---
# ## Tratamento condicional

# %%
#Verificar os valores nulos da coluna Condominio
df_residencial[df_residencial.Condominio.isnull()]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 5             Apartamento              Vista Alegre        3      1       0
# 7      Casa de Condomínio           Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                     Ramos        2      2       0
# 10            Apartamento                    Centro        1      0       0
# ...                   ...                       ...      ...    ...     ...
# 32859                Casa              Campo Grande        1      0       0
# 32865        Casa de Vila                    Pavuna        2      0       0
# 32893                Casa  Recreio dos Bandeirantes        4      2       2
# 32911                Casa             Bento Ribeiro        2      1       0
# 32931                Casa                    Centro        5      0       1
#
#        Area    Valor  Condominio  IPTU
# ...

# %%
#Verificar quais tipos de residencia tem valores nulos
df_residencial.Tipo[df_residencial.Condominio.isnull()].drop_duplicates()
# Out:
# 1                    Casa
# 5             Apartamento
# 7      Casa de Condomínio
# 117          Casa de Vila
# 536             Quitinete
# Name: Tipo, dtype: object

# %%
df_residencial[(df_residencial.Tipo == "Apartamento") & (df_residencial.Condominio.isnull())]
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# 194    Apartamento  Barra da Tijuca        1      1       1    65  2350.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             NaN   NaN
# 10            NaN   NaN
# ...

# %%
df_residencial.fillna(0, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df_residencial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22571 entries, 0 to 32958
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22571 non-null  object
#  1   Bairro      22571 non-null  object
#  2   Quartos     22571 non-null  int64
#  3   Vagas       22571 non-null  int64
#  4   Suites      22571 non-null  int64
#  5   Area        22571 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  22571 non-null  float64
#  8   IPTU        22571 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ---
# ## Atribuição de novos valores

# %%
# Calcular o valor bruto de cada imovel
df_residencial["Valor Bruto"] = df_residencial["Valor"] + df_residencial["Condominio"] + df_residencial["IPTU"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto
# 0      1700.0       500.0  60.0       2260.0
# ...

# %%
# Calcular os valor por m²
df_residencial["Valor por m²"] = (df_residencial["Valor"] / df_residencial["Area"]).round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor por m²
# ...

# %%
# Definir tipos precisos de imoveis
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila', "Quitinete"]
df_residencial["Tipo Agregado"] = df_residencial.Tipo.apply(lambda x: "Casa" if x in casa else "Apartamento")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor por m² Tipo Agregado
# ...

# %% [markdown]
# ---
# ## Estatistica Descritiva

# %%
media_valores_residencias = df_residencial.Valor.mean().round(3)
print(f"O valor dos imoveis em média é de R$ {media_valores_residencias}")
# Out:
# O valor dos imoveis em média é de R$ 4985.73

# %%
#Vizualizar os bairros que consta na base de dados
df_residencial.Bairro.unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Vista Alegre', 'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Praça Seca', 'Piedade', 'Lagoa', 'Catete',
#        'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
#        'Rocha Miranda', 'Engenho Novo', 'Engenho de Dentro',
#        'Cidade Nova', 'Pilares', 'Tomás Coelho', 'Água Santa',
#        'São Cristóvão', 'Ilha do Governador', 'Jardim Sulacap',
#        'Oswaldo Cruz', 'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque',
# ...

# %%
#Média dos valores dos bairros de alto padrão do RJ
bairros_alto_padrao = ["Botafogo", "Catete", "Copacabana", "Ipanema", "Leblon", "Flamengo", "Barra da Tijuca", "Lagoa", "Joá"]
imoveis_alto_padrao = df_residencial[df_residencial.Bairro.isin(bairros_alto_padrao)].drop_duplicates()
media_valores_alto_padrao = imoveis_alto_padrao.Valor.mean().round(2)
print(f"Média dos valores dos imoveis de alto padrão é de R$ {media_valores_alto_padrao}")
# Out:
# Média dos valores dos imoveis de alto padrão é de R$ 6866.44

# %%
grupo_bairros_alto_padrao = imoveis_alto_padrao.groupby("Bairro")

# %%
#Média por bairros de alto padrão
for bairro, dado in grupo_bairros_alto_padrao:
  print(f"Média dos valores dos imoveis no bairro {bairro}: R$ {dado.Valor.mean().round(2)}")
# Out:
# Média dos valores dos imoveis no bairro Barra da Tijuca: R$ 7080.56
# Média dos valores dos imoveis no bairro Botafogo: R$ 8826.83
# Média dos valores dos imoveis no bairro Catete: R$ 2272.52
# Média dos valores dos imoveis no bairro Copacabana: R$ 4096.22
# Média dos valores dos imoveis no bairro Flamengo: R$ 4111.37
# Média dos valores dos imoveis no bairro Ipanema: R$ 9476.14
# Média dos valores dos imoveis no bairro Joá: R$ 16773.48
# Média dos valores dos imoveis no bairro Lagoa: R$ 8183.83
# Média dos valores dos imoveis no bairro Leblon: R$ 8794.88

# %%
grupo_bairros_todos = df_residencial.groupby("Bairro")

# %%
#Média de todos os bairros
media_valores_dos_bairros = []
for bairro, dado in grupo_bairros_todos:
  media = dado.Valor.mean().round(2)
  media_bairros = {"Bairro":bairro, "Media dos valores":media}
  media_valores_dos_bairros.append(media_bairros)

# %%
df_media_bairros = pd.DataFrame(media_valores_dos_bairros)

# %%
df_media_bairros
# Out:
#                 Bairro  Media dos valores
# 0             Abolição            1195.62
# 1    Alto da Boa Vista            3966.67
# 2             Anchieta             784.29
# 3              Andaraí            1463.03
# 4                 Anil            1987.37
# ..                 ...                ...
# 149     Vila Valqueire            1741.80
# 150      Vila da Penha            1220.16
# 151       Vista Alegre            1087.14
# 152              Zumbi            2150.00
# 153         Água Santa             860.00
#
# [154 rows x 2 columns]

# %%
grupo_bairros_todos.Valor.describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            16.0  1195.62   410.90   800.0   900.0  1190.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             7.0   784.29   150.21   600.0   695.0   700.0   900.0
# Andaraí             98.0  1463.03   406.34   700.0  1200.0  1400.0  1650.0
# Anil                76.0  1987.37  1491.59   300.0  1052.5  1345.0  2600.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      50.0  1741.80  2162.44   800.0  1000.0  1250.0  1675.0
# Vila da Penha      124.0  1220.16   611.88   450.0   900.0  1100.0  1300.0
# Vista Alegre        21.0  1087.14   196.52   700.0   900.0  1100.0  1200.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa          10.0   860.00   164.65   600.0   800.0   850.0   925.0
#
#                        max
# Bairro
# ...

# %%
grupo_bairros_todos.Valor.aggregate(["min", "max", "sum"]).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                    Mínimo   Máximo       sum
# Bairro
# Abolição            800.0   2300.0   19130.0
# Alto da Boa Vista   600.0  15000.0   23800.0
# Anchieta            600.0   1000.0    5490.0
# Andaraí             700.0   2950.0  143377.0
# Anil                300.0   7000.0  151040.0
# ...                   ...      ...       ...
# Vila Valqueire      800.0  16000.0   87090.0
# Vila da Penha       450.0   4500.0  151300.0
# Vista Alegre        700.0   1400.0   22830.0
# Zumbi              1600.0   2700.0    4300.0
# Água Santa          600.0   1200.0    8600.0
#
# [154 rows x 3 columns]

# %% [markdown]
# * Visualização dos dados com gráfico

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
figura = grupo_bairros_todos.mean().plot.bar(color = 'blue')
figura.set_ylabel('Valor do Aluguel')
figura.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')
